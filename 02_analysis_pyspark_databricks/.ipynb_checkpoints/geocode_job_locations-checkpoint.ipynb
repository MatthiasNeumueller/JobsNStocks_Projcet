# %%
# %run "./requiredPackages"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: beautifulsoup4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (4.10.0)
# Requirement already satisfied: soupsieve&gt;1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (from beautifulsoup4) (2.3.1)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: fuzzywuzzy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (0.18.0)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: yfinance in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (0.1.68)
# Requirement already satisfied: multitasking&gt;=0.0.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas&gt;=0.24 in /databricks/python3/lib/python3.8/site-packages (from yfinance) (1.2.4)
# Requirement already satisfied: lxml&gt;=4.5.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (from yfinance) (4.7.1)
# Requirement already satisfied: numpy&gt;=1.15 in /databricks/python3/lib/python3.8/site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: requests&gt;=2.26 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: pytz&gt;=2017.3 in /databricks/python3/lib/python3.8/site-packages (from pandas&gt;=0.24-&gt;yfinance) (2020.5)
# Requirement already satisfied: python-dateutil&gt;=2.7.3 in /databricks/python3/lib/python3.8/site-packages (from pandas&gt;=0.24-&gt;yfinance) (2.8.1)
# Requirement already satisfied: six&gt;=1.5 in /databricks/python3/lib/python3.8/site-packages (from python-dateutil&gt;=2.7.3-&gt;pandas&gt;=0.24-&gt;yfinance) (1.15.0)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.26-&gt;yfinance) (2020.12.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (from requests&gt;=2.26-&gt;yfinance) (2.0.10)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.26-&gt;yfinance) (1.25.11)
# Requirement already satisfied: idna&lt;4,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.26-&gt;yfinance) (2.10)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: python-Levenshtein in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (0.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from python-Levenshtein) (52.0.0)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: pymongo in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (4.0.1)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: dnspython in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (2.1.0)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Collecting ssl
#   Downloading ssl-1.16.tar.gz (33 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -c &#39;import sys, setuptools, tokenize; sys.argv[0] = &#39;&#34;&#39;&#34;&#39;/tmp/pip-install-ll0c4aiq/ssl_a54eab5a18534170a9ec17a760e0d7e9/setup.py&#39;&#34;&#39;&#34;&#39;; __file__=&#39;&#34;&#39;&#34;&#39;/tmp/pip-install-ll0c4aiq/ssl_a54eab5a18534170a9ec17a760e0d7e9/setup.py&#39;&#34;&#39;&#34;&#39;;f=getattr(tokenize, &#39;&#34;&#39;&#34;&#39;open&#39;&#34;&#39;&#34;&#39;, open)(__file__);code=f.read().replace(&#39;&#34;&#39;&#34;&#39;\r\n&#39;&#34;&#39;&#34;&#39;, &#39;&#34;&#39;&#34;&#39;\n&#39;&#34;&#39;&#34;&#39;);f.close();exec(compile(code, __file__, &#39;&#34;&#39;&#34;&#39;exec&#39;&#34;&#39;&#34;&#39;))&#39; egg_info --egg-base /tmp/pip-pip-egg-info-psmpx6c9
#          cwd: /tmp/pip-install-ll0c4aiq/ssl_a54eab5a18534170a9ec17a760e0d7e9/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File &#34;&lt;string&gt;&#34;, line 1, in &lt;module&gt;
#       File &#34;/tmp/pip-install-ll0c4aiq/ssl_a54eab5a18534170a9ec17a760e0d7e9/setup.py&#34;, line 33
#         print &#39;looking for&#39;, f
#               ^
#     SyntaxError: Missing parentheses in call to &#39;print&#39;. Did you mean print(&#39;looking for&#39;, f)?
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/83/21/f469c9923235f8c36d5fd5334ed11e2681abad7e0032c5aba964dcaf9bbb/ssl-1.16.tar.gz#sha256=ac21156fee6aee9eb8d765bbb16f5f49492d81ff4b22f7b8fc001d2251120930 (from https://pypi.org/simple/ssl/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading ssl-1.15.tar.gz (32 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -c &#39;import sys, setuptools, tokenize; sys.argv[0] = &#39;&#34;&#39;&#34;&#39;/tmp/pip-install-ll0c4aiq/ssl_37ade3ea89bd43fc9c1d2fc2c985e326/setup.py&#39;&#34;&#39;&#34;&#39;; __file__=&#39;&#34;&#39;&#34;&#39;/tmp/pip-install-ll0c4aiq/ssl_37ade3ea89bd43fc9c1d2fc2c985e326/setup.py&#39;&#34;&#39;&#34;&#39;;f=getattr(tokenize, &#39;&#34;&#39;&#34;&#39;open&#39;&#34;&#39;&#34;&#39;, open)(__file__);code=f.read().replace(&#39;&#34;&#39;
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %run "./supportFunctions"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: beautifulsoup4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (4.10.0)
# Requirement already satisfied: soupsieve&gt;1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (from beautifulsoup4) (2.3.1)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: fuzzywuzzy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (0.18.0)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: yfinance in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (0.1.68)
# Requirement already satisfied: multitasking&gt;=0.0.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas&gt;=0.24 in /databricks/python3/lib/python3.8/site-packages (from yfinance) (1.2.4)
# Requirement already satisfied: lxml&gt;=4.5.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (from yfinance) (4.7.1)
# Requirement already satisfied: numpy&gt;=1.15 in /databricks/python3/lib/python3.8/site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: requests&gt;=2.26 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: pytz&gt;=2017.3 in /databricks/python3/lib/python3.8/site-packages (from pandas&gt;=0.24-&gt;yfinance) (2020.5)
# Requirement already satisfied: python-dateutil&gt;=2.7.3 in /databricks/python3/lib/python3.8/site-packages (from pandas&gt;=0.24-&gt;yfinance) (2.8.1)
# Requirement already satisfied: six&gt;=1.5 in /databricks/python3/lib/python3.8/site-packages (from python-dateutil&gt;=2.7.3-&gt;pandas&gt;=0.24-&gt;yfinance) (1.15.0)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.26-&gt;yfinance) (2020.12.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (from requests&gt;=2.26-&gt;yfinance) (2.0.10)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.26-&gt;yfinance) (1.25.11)
# Requirement already satisfied: idna&lt;4,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.26-&gt;yfinance) (2.10)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: python-Levenshtein in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (0.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from python-Levenshtein) (52.0.0)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: pymongo in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (4.0.1)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: dnspython in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/lib/python3.8/site-packages (2.1.0)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Collecting ssl
#   Downloading ssl-1.16.tar.gz (33 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -c &#39;import sys, setuptools, tokenize; sys.argv[0] = &#39;&#34;&#39;&#34;&#39;/tmp/pip-install-ll0c4aiq/ssl_a54eab5a18534170a9ec17a760e0d7e9/setup.py&#39;&#34;&#39;&#34;&#39;; __file__=&#39;&#34;&#39;&#34;&#39;/tmp/pip-install-ll0c4aiq/ssl_a54eab5a18534170a9ec17a760e0d7e9/setup.py&#39;&#34;&#39;&#34;&#39;;f=getattr(tokenize, &#39;&#34;&#39;&#34;&#39;open&#39;&#34;&#39;&#34;&#39;, open)(__file__);code=f.read().replace(&#39;&#34;&#39;&#34;&#39;\r\n&#39;&#34;&#39;&#34;&#39;, &#39;&#34;&#39;&#34;&#39;\n&#39;&#34;&#39;&#34;&#39;);f.close();exec(compile(code, __file__, &#39;&#34;&#39;&#34;&#39;exec&#39;&#34;&#39;&#34;&#39;))&#39; egg_info --egg-base /tmp/pip-pip-egg-info-psmpx6c9
#          cwd: /tmp/pip-install-ll0c4aiq/ssl_a54eab5a18534170a9ec17a760e0d7e9/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File &#34;&lt;string&gt;&#34;, line 1, in &lt;module&gt;
#       File &#34;/tmp/pip-install-ll0c4aiq/ssl_a54eab5a18534170a9ec17a760e0d7e9/setup.py&#34;, line 33
#         print &#39;looking for&#39;, f
#               ^
#     SyntaxError: Missing parentheses in call to &#39;print&#39;. Did you mean print(&#39;looking for&#39;, f)?
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/83/21/f469c9923235f8c36d5fd5334ed11e2681abad7e0032c5aba964dcaf9bbb/ssl-1.16.tar.gz#sha256=ac21156fee6aee9eb8d765bbb16f5f49492d81ff4b22f7b8fc001d2251120930 (from https://pypi.org/simple/ssl/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading ssl-1.15.tar.gz (32 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5d10845-8a8a-4dfd-8224-2446b6d8f935/bin/python -c &#39;import sys, setuptools, tokenize; sys.argv[0] = &#39;&#34;&#39;&#34;&#39;/tmp/pip-install-ll0c4aiq/ssl_37ade3ea89bd43fc9c1d2fc2c985e326/setup.py&#39;&#34;&#39;&#34;&#39;; __file__=&#39;&#34;&#39;&#34;&#39;/tmp/pip-install-ll0c4aiq/ssl_37ade3ea89bd43fc9c1d2fc2c985e326/setup.py&#39;&#34;&#39;&#34;&#39;;f=getattr(tokenize, &#39;&#34;&#39;&#34;&#39;open&#39;&#34;&#39;&#34;&#39;, open)(__file__);code=f.read().replace(&#39;&#34;&#39;
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pyspark
from pyspark import SparkContext
from pyspark.sql import SparkSession, SQLContext, Row
from pyspark.sql.functions import split, col, regexp_extract, regexp_replace, to_timestamp, udf, unix_timestamp, concat_ws
from pyspark.sql.types import StringType

from pymongo import MongoClient
from json import loads
import pymongo
import ssl

from bson.objectid import ObjectId
import re
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# initiate spark session
spark = (SparkSession 
    .builder 
    .appName("geocode_jobs") 
    .getOrCreate()
 )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# load data from mongo db
df = (spark.read
      .format("mongo")
      .option("uri","mongodb+srv://attila:JS8WMhoQB65LynxB@cluster0.gu4ru.mongodb.net/Group_B1_JobStock_db.jobs")
      .load()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = (df
       .withColumn('country', regexp_extract(col('location'), '(Germany)|(Austria)|(Switzerland)|(Anywhere)',0))
       .withColumn('city', regexp_replace(col('location'), '(\s)|(,)|(\\(.*\\))|(Germany)|(Austria)|(Switzerland)',""))
       .withColumn('date', to_timestamp(df.date, 'yyyy-MM-dd'))
      )
#df2.groupBy("country","city", "date").count().show(100)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# concat cleat city and country for geocoding
df = df.withColumn("location_geocoding", concat_ws(", ", "city",  "country"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#geocode locations
geo_coder_UDF = udf(lambda x : geo_coder(x))
df = df.withColumn('geo_code', geo_coder_UDF(col('location_geocoding')))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# apperently geo_code is a string (and not a list of strings)
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _id: struct (nullable = true)
#     |-- oid: string (nullable = true)
# -- company_name: string (nullable = true)
# -- date: timestamp (nullable = true)
# -- description: string (nullable = true)
# -- detected_extensions: struct (nullable = true)
#     |-- posted_at: string (nullable = true)
#     |-- salary: string (nullable = true)
#     |-- schedule_type: string (nullable = true)
#     |-- work_from_home: boolean (nullable = true)
# -- extensions: array (nullable = true)
#     |-- element: string (containsNull = true)
# -- job_id: string (nullable = true)
# -- location: string (nullable = true)
# -- location_extended: struct (nullable = true)
#     |-- city: string (nullable = true)
#     |-- country: string (nullable = true)
#     |-- longitude: integer (nullable = true)
#     |-- latitude: integer (nullable = true)
# -- thumbnail: string (nullable = true)
# -- title: string (nullable = true)
# -- via: string (nullable = true)
# -- country: string (nullable = true)
# -- city: string (nullable = true)
# -- location_geocoding: string (nullable = false)
# -- geo_code: string (nullable = true)
#
# </div>

# %%
#Connect to MogoDB
client = MongoClient('mongodb+srv://attila:JS8WMhoQB65LynxB@cluster0.gu4ru.mongodb.net')
mycol = client.Group_B1_JobStock_db.jobs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#write back extendend location info to mongo db. takes ages. map on an rdd does't seem to work here as mycon cannot be parallelized 
df2 = df.select("_id", "city", "country","geo_code")
for row in df2.rdd.collect():
    oId = ObjectId(row["_id"]["oid"])
    lonlat = re.sub("[\\[\\]]", "", row["geo_code"]).split(",") # this is needed only because geocoder returned a string
    res = mycol.update_one(
       { "_id": oId },
       { "$set": { "location_extended" : {"city" : row["city"] , 
                                          "country" : row["country"], 
                                          "longitude" : float(lonlat[0]), 
                                          "latitude" :  float(lonlat[1]) }}}
    )
    print(f" id { oId }, matched {res.matched_count}, modified {res.modified_count}, id {res.upserted_id}, ack {res.acknowledged}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"> id 61bf583b862fcdcc42a8656d, matched 1, modified 1, id None, ack True
#  id 61bf583b862fcdcc42a8656e, matched 1, modified 1, id None, ack True
#  id 61bf583b862fcdcc42a8656f, matched 1, modified 1, id None, ack True
#  id 61bf583b862fcdcc42a86570, matched 1, modified 1, id None, ack True
#  id 61bf583b862fcdcc42a86571, matched 1, modified 1, id None, ack True
#  id 61bf583b862fcdcc42a86572, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86573, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86574, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86575, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86576, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86577, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86578, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86579, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a8657a, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a8657b, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a8657c, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a8657d, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a8657e, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a8657f, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86580, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86581, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86582, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86583, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86584, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86585, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86586, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86587, matched 1, modified 1, id None, ack True
#  id 61bf583c862fcdcc42a86588, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a86589, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a8658a, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a8658b, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a8658c, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a8658d, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a8658e, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a8658f, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a86590, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a86591, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a86592, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a86593, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a86594, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a86595, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a86596, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a86597, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a86598, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a86599, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a8659a, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a8659b, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a8659c, matched 1, modified 1, id None, ack True
#  id 61bf583d862fcdcc42a8659d, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a8659e, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a8659f, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865a0, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865a1, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865a2, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865a3, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865a4, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865a5, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865a6, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865a7, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865a8, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865a9, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865aa, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865ab, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865ac, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865ad, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865ae, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865af, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865b0, matched 1, modified 1, id None, ack True
#  id 61bf583e862fcdcc42a865b1, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865b2, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865b3, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865b4, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865b5, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865b6, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865b7, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865b8, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865b9, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865ba, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865bb, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865bc, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865bd, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865be, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865bf, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865c0, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865c1, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865c2, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865c3, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865c4, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865c5, matched 1, modified 1, id None, ack True
#  id 61bf583f862fcdcc42a865c6, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865c7, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865c8, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865c9, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865ca, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865cb, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865cc, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865cd, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865ce, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865cf, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865d0, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865d1, matched 1, modified 1, id None, ack True
#  id 61bf5840862fcdcc42a865d2, matched 1, modified 1, id None, ack True
#  id 61bf5841862fcdcc42a865d3, matched 1, modified 1, id None, ack True
#  id 61bf5841862fcdcc42a865d4, matched 1, modified 1, id None, ack True
#  id 61bf5841862fcdcc42a865d5, matched 1, modified 1, id None, ack True
#  id 61bf5841862fcdcc42a865d6, matched 1, modified 1, id None, ack True
#  id 61bf5841862fcdcc42a865d7, matched 1, modified 1, id None, ack True
#  id 61bf5841862fcdcc42a865d8, matched 1, modified 1, id None, ack True
#  id
